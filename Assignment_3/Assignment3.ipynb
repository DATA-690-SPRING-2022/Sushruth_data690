# %% [markdown]
# <a href="https://colab.research.google.com/github/SushruthDt/Sushruth_data690/blob/main/Assignment_3/Assignment3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Assignment 3
# ------------------------------------------------------
# - Student Id - MM73053
# - Student Name - Sushruth
# - Title - " DATA 690 Special Topics in Data Science (06.7928) "
#
# #### Write a program that generates 100 random integers between 0 and 9.

# %% [markdown]
# ## 1. Print them in a 10 by 10 matrix neatly arranged like the following (one space between each number):
# ![image.png](data:image/png;base64,...)

# %%
import random #Importing required library

# %%
for x in range(10):
 for i in range(10):
   print(random.randint(0,9), end=' ') #Using RandInt() to generate randomnumber between 0 and 9
 print(' ')
# Out:
# 8 2 7 3 6 1 2 5 6 3
# 2 3 1 7 3 5 6 8 3 1
# 6 9 4 7 9 2 2 3 0 2
# 0 3 4 0 3 3 2 7 5 0
# 6 3 5 4 5 2 1 3 9 2
# 3 5 0 7 2 3 8 6 0 4
# 0 7 1 0 6 1 7 5 1 6
# 2 1 3 1 8 3 2 0 4 4
# 7 0 8 7 7 7 4 1 2 9
# 6 9 3 3 1 2 8 7 8 5

# %% [markdown]
# ## 2. If the random number is an odd number, print "@" instead. like the following:
# ![image.png](data:image/png;base64,...)

# %%
for x in range(10):
    for i in range(10):
     num = random.randint(0,9) #Using RandInt() to generate randomnumber between 0 and 9
     if num % 2 == 0: #Check if the number is even
        print(num, end=' ')

     else: # when number is odd
        print('@', end=' ')

    print(' ')
# Out:
# @ 0 @ 8 0 @ 6 8 @ @
# @ @ 2 8 @ @ 6 @ 6 @
# @ @ 0 @ 4 4 0 4 4 8
# 2 @ 4 @ 8 2 4 @ @ 2
# @ 0 0 6 6 @ 6 8 @ 0
# 8 @ 6 @ 8 @ @ @ 6 @
# 8 @ @ @ @ 6 6 @ @ @
# 6 2 0 @ @ 8 @ 4 @ 2
# 0 @ 6 4 2 4 0 @ @ 8
# 0 8 @ 0 6 8 4 @ @ @

# %% [markdown]
# ## 3. Calculate and Print the total of each row like the following (use "*" to separate the total from the numbers):
#
# ![image.png](data:image/png;base64,...)

# %%
for x in range(10):
  sum = 0
  for i in range(10):
    num = random.randint(0,9) #Using RandInt() to generate randomnumber between 0 and 9
    sum = sum + num #Storing summation values in sum variable
    print(num, end=' ')

  print('*', sum) #Printing sum at the end of inner for loop
# Out:
# 1 8 1 3 8 9 2 9 1 0 * 42
# 8 6 5 0 1 7 4 1 3 8 * 43
# 3 5 0 9 2 1 0 7 3 6 * 36
# 3 3 5 3 3 2 5 8 4 6 * 42
# 0 8 6 1 8 0 7 7 0 5 * 42
# 5 2 2 0 4 8 1 4 8 2 * 36
# 6 8 2 5 4 9 8 0 4 0 * 46
# 9 8 2 0 5 3 8 0 1 2 * 38
# 1 7 8 0 1 2 4 8 3 5 * 39
# 5 1 7 2 5 8 2 7 2 4 * 43

# %% [markdown]
# ## 4. Optional: Surround the matrix with asterisks (*) like the following:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
print('***********************') #Starting boundary
for x in range(10):
  print('*', end=' ') # print * at start of iteration
  for i in range(10): 
    print(random.randint(0,9), end=' ') #Using RandInt() to generate randomnumber between 0 and 9
  print('*') #print * at end of iteration
print('***********************') # End Boundary
# Out:
# ***********************
# * 3 1 1 5 4 6 7 6 4 3 *
# * 2 7 5 9 1 5 1 4 5 1 *
# * 3 1 8 1 1 8 1 3 6 9 *
# * 6 7 5 0 9 4 4 1 3 2 *
# * 0 0 7 2 3 5 2 2 5 0 *
# * 7 3 4 4 9 2 0 5 3 2 *
# * 6 2 1 0 2 5 3 3 3 8 *
# * 0 4 0 8 6 0 3 1 2 4 *
# * 2 3 2 0 7 9 5 3 9 5 *
# * 4 1 9 3 0 9 1 1 3 3 *
# ***********************

# %% [markdown]
# ## 5. Optional (challenging): Calculate and Print the total of each row and column like the following:
# ![image.png](data:image/png;base64,...)

# %%
print('***********************')
for x in range(10):
  sum = 0
  print('*', end=' ')
  for i in range(10): 
     num = random.randint(0,9) #Using RandInt() to generate randomnumber between 0 and 9
     sum = sum + num
     print(num, end=' ')
  print('*',sum)
print('***********************')

# Not sure how I can try to sum the values of colunms? 
## Probably I should try storing values in form of matrices [x,y] and summate for this
# Out:
# ***********************
# * 8 1 1 2 8 1 9 0 4 2 * 36
# * 4 1 8 7 1 5 0 3 5 7 * 41
# * 8 9 6 6 3 9 4 0 0 6 * 51
# * 6 2 7 9 4 0 5 0 4 4 * 41
# * 4 3 0 5 9 6 9 9 9 9 * 63
# * 4 8 4 5 4 6 0 3 8 0 * 42
# * 7 6 5 5 0 5 4 2 0 5 * 39
# * 9 1 2 1 0 8 4 6 5 9 * 45
# * 8 4 4 0 7 5 8 0 1 4 * 41
# * 5 4 5 9 5 5 2 9 0 1 * 45
# ***********************
